# %% [markdown]
# # MCMC
#
# $$T(x|\nu,\sigma,\mu)=\frac{\Gamma\left(\frac{\nu+1}{2}\right)}{\Gamma\left(\frac{\nu}{2}\right)\sqrt{\nu\pi\sigma}}\left(1+\frac{1}{\nu}\left(\frac{x-\mu}{\sigma}\right)^{2}\right)^{-\frac{\nu+1}{2}}$$
#
#
# #### a)
# Run your code trying four different jump size scalings, $\alpha=0.01, \alpha=0.1, \alpha=1$ and $\alpha=10$,
# Visually inspect the chains. Which one appears to be exploring the distribution most effectively?

# %%
import numpy as np
import scipy
import scipy.stats
import matplotlib as mpl   
import matplotlib.pyplot as plt
from scipy.special import gamma
# %matplotlib inline

# %%
def f(x,nu,mu,std):
    return (gamma((nu+1)/2)/(gamma(nu/2)*np.sqrt(nu*np.pi*std)))*(1+(1/nu)*((x-mu)/std)**2)**(-(nu+1)/2)

# %% [markdown]
# $ \nu = 3$
#
# $\sigma = 1$
#
# $\mu = 1.5$

# %%
nu=3
sigma=1
mu=1.5

# %% [markdown]
# $\alpha=0.01$

# %%
alpha=0.01

# %%
n=100
x=np.zeros(n)
x[0]=0

acep=0

for i in range(0, n-1):
    
    y=x[i]+np.random.uniform(-alpha,alpha)
    
    if np.random.rand() < min(1,f(y,nu,mu,sigma)/f(x[i],nu,mu,sigma)):
        x[i+1]=y
        acep+=1
    else:
        x[i+1]=x[i]
    
print("The acceptance was from: ", acep/n*100,"%")
# Out:
# The acceptance was from:  99.0 %

# %%
plt.plot(x)

# %% [markdown]
# $\alpha=0.1$

# %%
alpha2=0.1
n=100
x=np.zeros(n)
x[0]=0

acep=0

for i in range(0, n-1):
    
    y=x[i]+np.random.uniform(-alpha2,alpha2)
    
    if np.random.rand() < min(1,f(y,nu,mu,sigma)/f(x[i],nu,mu,sigma)):
        x[i+1]=y
        acep+=1
    else:
        x[i+1]=x[i]
    
print("The acceptance was from:  ", acep/n*100,"%")
# Out:
# The acceptance was from:   91.0 %

# %%
plt.plot(x)

# %% [markdown]
# $\alpha=1$

# %%
alpha3=1
n=100
x=np.zeros(n)
x[0]=0

acep=0

for i in range(0, n-1):
    
    y=x[i]+np.random.uniform(-alpha3,alpha3)
    
    if np.random.rand() < min(1,f(y,nu,mu,sigma)/f(x[i],nu,mu,sigma)):
        x[i+1]=y
        acep+=1
    else:
        x[i+1]=x[i]
    
print("The acceptance was from:  ", acep/n*100,"%")
# Out:
# The acceptance was from:   83.0 %

# %%
plt.plot(x)

# %% [markdown]
# $\alpha=10$

# %%
alpha4=10
n=100
x=np.zeros(n)
x[0]=0

acep=0

for i in range(0, n-1):
    
    y=x[i]+np.random.uniform(-alpha4,alpha4)
    
    if np.random.rand() < min(1,f(y,nu,mu,sigma)/f(x[i],nu,mu,sigma)):
        x[i+1]=y
        acep+=1
    else:
        x[i+1]=x[i]
    
print("The acceptance was from:  ", acep/n*100,"%")
# Out:
# The acceptance was from:   21.0 %

# %%
plt.plot(x)

# %% [markdown]
# ###### The one that best describes the behavior is the first one with $\alpha = 10$, since it is close to $0$

# %% [markdown]
# #### b)
#
# Using the same previous $4$ sets of jumps sizes, run your code for $N$ $=$ $1000$ iterations and use
# the output to produce histograms of the $\{xi\}$. Plot them against the target distribution $T (x|\nu, \sigma, \mu)$. Which
# distribution looks the best

# %%
nu=3
sigma=1
mu=1.5

alpha=0.01
n=1000
x=np.zeros(n)
x[0]=0

acep=0

for i in range(0, n-1):
    
    y=x[i]+np.random.uniform(-alpha,alpha)
    
    if np.random.rand() < min(1,f(y,nu,mu,sigma)/f(x[i],nu,mu,sigma)):
        x[i+1]=y
        acep+=1
    else:
        x[i+1]=x[i]
    
print("The acceptance was from: ", acep/n*100,"%")


plt.hist(x,density=True,bins=40)
xs=np.linspace(-0.5,0.5,100)
plt.plot(xs,f(xs,nu,mu,sigma))
# Out:
# The acceptance was from:  99.7 %

# %%
plt.plot(x, color ="red")

# %%
nu=3
sigma=1
mu=1.5

alpha2=0.1
n=1000
x=np.zeros(n)
x[0]=0

acep=0

for i in range(0, n-1):
    
    y=x[i]+np.random.uniform(-alpha2,alpha2)
    
    if np.random.rand() < min(1,f(y,nu,mu,sigma)/f(x[i],nu,mu,sigma)):
        x[i+1]=y
        acep+=1
    else:
        x[i+1]=x[i]
    
print("The acceptance was from: ", acep/n*100,"%")


plt.hist(x,density=True,bins=40)
xs=np.linspace(-2,4,100)
plt.plot(xs,f(xs,nu,mu,sigma))
# Out:
# The acceptance was from:  98.1 %

# %%
plt.plot(x, color="red")

# %%
nu=3
sigma=1
mu=1.5

alpha3=1
n=1000
x=np.zeros(n)
x[0]=0

acep=0

for i in range(0, n-1):
    
    y=x[i]+np.random.uniform(-alpha3,alpha3)
    
    if np.random.rand() < min(1,f(y,nu,mu,sigma)/f(x[i],nu,mu,sigma)):
        x[i+1]=y
        acep+=1
    else:
        x[i+1]=x[i]
    
print("The acceptance was from: ", acep/n*100,"%")


plt.hist(x,density=True,bins=40)
xs=np.linspace(-4,8,100)
plt.plot(xs,f(xs,nu,mu,sigma))
# Out:
# The acceptance was from:  82.0 %

# %%
plt.plot(x, color="red")

# %%
nu=3
sigma=1
mu=1.5

alpha4=10
n=1000
x=np.zeros(n)
x[0]=0

acep=0

for i in range(0, n-1):
    
    y=x[i]+np.random.uniform(-alpha4,alpha4)
    
    if np.random.rand() < min(1,f(y,nu,mu,sigma)/f(x[i],nu,mu,sigma)):
        x[i+1]=y
        acep+=1
    else:
        x[i+1]=x[i]
    
print("The acceptance was from: ", acep/n*100,"%")


plt.hist(x,density=True,bins=40)
xs=np.linspace(-10,10,100)
plt.plot(xs,f(xs,nu,mu,sigma))
# Out:
# The acceptance was from:  22.6 %

# %%
plt.plot(x, color="red")

# %% [markdown]
# $\fbox{The distribution of the 1000 iterations is better seen.}$

# %% [markdown]
# #### c)
# Have your code compute the acceptance fraction for the proposed jumps (i.e., the fraction of the
# proposed jumps that are accepted). Does a high acceptance rate necessarily mean efficient exploration of the
# distribution?
